# %%
import os

def delete_folder(folder_path):
    """Delete the specified folder and all its contents."""
    # delete folder called "trajs_after_training and checkpoints"
    trajs_folder = os.path.join(folder_path, "trajs_after_training")
    checkpoints_folder = os.path.join(folder_path, "checkpoints")
    if os.path.exists(trajs_folder):
        os.system(f"rm -rf {trajs_folder}")
        print(f"Deleted folder: {trajs_folder}")
    if os.path.exists(checkpoints_folder):
        os.system(f"rm -rf {checkpoints_folder}")
        print(f"Deleted folder: {checkpoints_folder}")




main_folder = "/home/robo/Projects/p3/results/alphaEst_randomPi_PiRange005-02/logs_scoring_sin-train_noReplacing/"
main_folder = "/home/robo/Projects/p3/results/alphaEst_randomPi_PiRange005-02/logs_scoring_sin-train_noReplacing/"
main_folder = "/home/robo/Projects/p3/results/alphaEst_randomPi_PiRange01-09/logs_gails_clean/aa_old/"
main_folder = "/home/robo/Projects/p3/results/alphaEst_randomPi_PiRange01-09/logs_scoring_sin-train_noReplacing_env8/"
main_folder = "/home/robo/Projects/p3/results/alphaEst_randomPi_PiRange005-015/logs_gails_noisy/aa_other_rlseeds_env8/"
main_folder = "/home/robo/Projects/p3/results/logs_scoring_sin-train_sort_uu_loss_noReplacing/alpha_025"
main_folder = "/home/robo/Projects/p3/results/work_station5090/alphaEst_randomPi_PiRange01-09_/logs_scoring_sin-train_noReplacing_expTopk_03"

sub_folders  = os.listdir(main_folder)
for sub_folder in sub_folders:
    folder_to_clean = os.path.join(main_folder, sub_folder)
    delete_folder(folder_to_clean)
# Out:
# Deleted folder: /home/robo/Projects/p3/results/work_station5090/alphaEst_randomPi_PiRange01-09_/logs_scoring_sin-train_noReplacing_expTopk_03/Ant-v4_scoring_SAC_NetAgentSeed_1-1_epochs_50_RLseed_0_alpha_0324-un_gail_finetune_500_itrs_scoring_stepnum30e5_both_uuloss_Nagent_expFine_T_agtFine_F_topk_expTopk_03_earlyStop30num/trajs_after_training
# Deleted folder: /home/robo/Projects/p3/results/work_station5090/alphaEst_randomPi_PiRange01-09_/logs_scoring_sin-train_noReplacing_expTopk_03/Ant-v4_scoring_SAC_NetAgentSeed_1-1_epochs_50_RLseed_0_alpha_0324-un_gail_finetune_500_itrs_scoring_stepnum30e5_both_uuloss_Nagent_expFine_T_agtFine_F_topk_expTopk_03_earlyStop30num/checkpoints
# ...
